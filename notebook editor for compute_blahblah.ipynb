# %%
# -*- coding: utf-8 -*-
import dataiku
import pandas as pd, numpy as np
from dataiku import pandasutils as pdu

# Read recipe inputs
modifyme = dataiku.Dataset("modifyme")
modifyme_df = modifyme.get_dataframe()


# Compute recipe outputs from inputs
# TODO: Replace this part by your actual code that computes the output, as a Pandas dataframe
# NB: DSS also supports other kinds of APIs for reading and writing data. Please see doc.

blahblah_df = modifyme_df # For this sample code, simply copy input to output


# Write recipe outputs
blahblah = dataiku.Dataset("blahblah")
blahblah.write_with_schema(blahblah_df)
